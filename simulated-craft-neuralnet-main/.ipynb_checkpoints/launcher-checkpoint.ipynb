# %%
# %run "generator.py"
# Out:
# [5, 5, 4]
# GENERATION: 0 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 10 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 20 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 30 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 40 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 50 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 60 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 70 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 80 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 90 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 100 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 110 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 120 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# GENERATION: 130 -- Highest Fitness: 1.2 | Time In: 1.13 | Goals: 0
# ...
